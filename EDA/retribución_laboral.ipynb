# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # ILOSTAT salario min mensual bruto (anual)

# %% [markdown]
# Fuente: ILOSTAT explorer https://www.ilo.org/shinyapps/bulkexplorer42/?lang=es&id=EAR_4MMN_CUR_NB_A

# %% [markdown]
# Salario mínimo nominal mensual bruto-Anual (en dó

# %%
df_salario_min = pd.read_csv(r'salario_minimo_mensual_bruto_anual_dolares.csv', sep=',', header=0)
df_salario_min
# Out:
#      ref_area ref_area.label   source               source.label  \
# 0         AFG     Afganistán  FX:3344  ADM - Legislación Laboral
# 1         AFG     Afganistán  FX:3344  ADM - Legislación Laboral
# 2         AFG     Afganistán  FX:3344  ADM - Legislación Laboral
# 3         AFG     Afganistán  FX:3344  ADM - Legislación Laboral
# 4         AFG     Afganistán  FX:3344  ADM - Legislación Laboral
# ...       ...            ...      ...                        ...
# 2937      ZMB         Zambia  FX:3252  ADM - Legislación Laboral
# 2938      ZMB         Zambia  FX:3252  ADM - Legislación Laboral
# 2939      ZMB         Zambia  FX:3252  ADM - Legislación Laboral
# 2940      ZMB         Zambia  FX:3252  ADM - Legislación Laboral
# 2941      ZMB         Zambia  FX:3252  ADM - Legislación Laboral
#
#             indicator                       indicator.label      classif1  \
# 0     EAR_4MMN_CUR_NB  Salario mínimo nominal mensual bruto  CUR_TYPE_USD
# ...

# %% [markdown]
# Información de dataframe

# %%
df_salario_min.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942 entries, 0 to 2941
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ref_area              2942 non-null   object
#  1   ref_area.label        2942 non-null   object
#  2   source                2942 non-null   object
#  3   source.label          2942 non-null   object
#  4   indicator             2942 non-null   object
#  5   indicator.label       2942 non-null   object
#  6   classif1              2942 non-null   object
#  7   classif1.label        2942 non-null   object
#  8   time                  2942 non-null   int64
#  9   obs_value             2942 non-null   float64
#  10  obs_status            53 non-null     object
#  11  obs_status.label      53 non-null     object
#  12  note_indicator        2942 non-null   object
#  13  note_indicator.label  2942 non-null   object
#  14  note_source           1223 non-null   object
# ...

# %% [markdown]
# Valores nulos por columna

# %%
df_salario_min.isnull().sum()
# Out:
# ref_area                   0
# ref_area.label             0
# source                     0
# source.label               0
# indicator                  0
# indicator.label            0
# classif1                   0
# classif1.label             0
# time                       0
# obs_value                  0
# obs_status              2889
# obs_status.label        2889
# note_indicator             0
# note_indicator.label       0
# note_source             1719
# note_source.label       1719
# dtype: int64

# %% [markdown]
# Valores duplicados

# %%
df_salario_min.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción del dataframe

# %%
# Valores numéricos
df_salario_min.describe()
# Out:
#               time    obs_value
# count  2942.000000  2942.000000
# mean   2010.516655   358.235180
# std       7.279776   503.741699
# min    1980.000000     0.080000
# 25%    2005.000000    61.202500
# 50%    2011.000000   151.165000
# 75%    2017.000000   394.950000
# max    2022.000000  4385.690000

# %%
# Valores no numéricos
df_salario_min.describe(include=[object])
# Out:
#        ref_area  ref_area.label   source               source.label  \
# count      2942            2942     2942                       2942
# unique      156             156      156                         14
# top         USA  Estados Unidos  FX:3255  ADM - Legislación Laboral
# freq         33              33       33                       2441
#
#               indicator                       indicator.label      classif1  \
# count              2942                                  2942          2942
# unique                1                                     1             1
# top     EAR_4MMN_CUR_NB  Salario mínimo nominal mensual bruto  CUR_TYPE_USD
# freq               2942                                  2942          2942
#
#                       classif1.label obs_status obs_status.label  \
# count                           2942         53               53
# unique                             1          1                1
# ...

# %% [markdown]
# Rango temporal de datos

# %%
df_salario_min['time'].value_counts()
# Out:
# 2020    143
# 2019    141
# 2017    141
# 2016    141
# 2018    140
# 2013    138
# 2015    135
# 2021    134
# 2011    132
# 2014    132
# 2012    131
# 2010    129
# 2009    127
# 2008    124
# 2007     98
# 2006     97
# 2005     96
# 2003     94
# 2004     93
# 2002     91
# 2000     90
# 2001     89
# 1999     70
# 2022     61
# 1998     48
# 1997     44
# 1996     41
# 1995     35
# 1994      2
# 1991      1
# 1981      1
# 1988      1
# 1992      1
# 1980      1
# Name: time, dtype: int64

# %% [markdown]
# Datos desde el año 1980 a 2020

# %% [markdown]
# ### Sugested Data-Wrangling

# %% [markdown]
# - [ ] Eliminar todas las  columnas distintas a: 'ref_area', 'time' y 'obs_value'

# %% [markdown]
# - [ ] Renombrar columnas

# %% [markdown]
# - [ ] Reducir marco temporal

# %% [markdown]
# # ILOSTAT Ganancias por hora promedio de asalariados.

# %% [markdown]
# Fuente: https://www.ilo.org/shinyapps/bulkexplorer21/?lang=es&id=SDG_0851_SEX_OCU_NB_A

# %%
df_ganancias_hora_asalariados = pd.read_csv(r'ganancias_promedio_asalariados', sep=',',header=0)
df_ganancias_hora_asalariados
# Out:
#       ref_area ref_area.label   source  \
# 0          AFG     Afganistán  BB:6361
# 1          AFG     Afganistán  BB:6361
# 2          AFG     Afganistán  BB:6361
# 3          AFG     Afganistán  BB:6361
# 4          AFG     Afganistán  BB:6361
# ...        ...            ...      ...
# 12301      ZWE       Zimbabwe  BA:1823
# 12302      ZWE       Zimbabwe  BA:1823
# 12303      ZWE       Zimbabwe  BA:1823
# 12304      ZWE       Zimbabwe  BA:1823
# 12305      ZWE       Zimbabwe  BA:1823
#
#                                  source.label            indicator  \
# 0      EIGH - Encuesta de Condiciones de Vida  SDG_0851_SEX_OCU_NB
# 1      EIGH - Encuesta de Condiciones de Vida  SDG_0851_SEX_OCU_NB
# 2      EIGH - Encuesta de Condiciones de Vida  SDG_0851_SEX_OCU_NB
# 3      EIGH - Encuesta de Condiciones de Vida  SDG_0851_SEX_OCU_NB
# 4      EIGH - Encuesta de Condiciones de Vida  SDG_0851_SEX_OCU_NB
# ...                                       ...                  ...
# ...

# %% [markdown]
# Información de dataframe

# %%
df_ganancias_hora_asalariados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12306 entries, 0 to 12305
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ref_area              12306 non-null  object
#  1   ref_area.label        12306 non-null  object
#  2   source                12306 non-null  object
#  3   source.label          12306 non-null  object
#  4   indicator             12306 non-null  object
#  5   indicator.label       12306 non-null  object
#  6   sex                   12306 non-null  object
#  7   sex.label             12306 non-null  object
#  8   classif1              12306 non-null  object
#  9   classif1.label        12306 non-null  object
#  10  time                  12306 non-null  int64
#  11  obs_value             12221 non-null  float64
#  12  obs_status            1734 non-null   object
#  13  obs_status.label      1734 non-null   object
#  14  note_classif          11 non-null     object
# ...

# %% [markdown]
# Valores nulos por columna

# %%
df_ganancias_hora_asalariados.isnull().sum()
# Out:
# ref_area                    0
# ref_area.label              0
# source                      0
# source.label                0
# indicator                   0
# indicator.label             0
# sex                         0
# sex.label                   0
# classif1                    0
# classif1.label              0
# time                        0
# obs_value                  85
# obs_status              10572
# obs_status.label        10572
# note_classif            12295
# note_classif.label      12295
# note_indicator              1
# note_indicator.label        1
# note_source                62
# note_source.label          62
# dtype: int64

# %% [markdown]
# Valores duplicados

# %%
df_ganancias_hora_asalariados.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción de Dataframe

# %%
# Valores numéricos
df_ganancias_hora_asalariados.describe()
# Out:
#                time     obs_value
# count  12306.000000  12221.000000
# mean    2012.867951   1860.546580
# std        5.955656   6278.806179
# min     1991.000000      0.210000
# 25%     2009.000000     10.460000
# 50%     2014.000000     33.160000
# 75%     2018.000000    316.000000
# max     2022.000000  97012.000000

# %%
# Valores no numéricos
df_ganancias_hora_asalariados.describe(include=[object])
# Out:
#        ref_area ref_area.label  source  \
# count     12306          12306   12306
# unique      125            125     151
# top         CHE          Suiza  BA:253
# freq        527            527     527
#
#                                   source.label            indicator  \
# count                                    12306                12306
# unique                                      74                    1
# top     EFT - Encuesta de la Fuerza de Trabajo  SDG_0851_SEX_OCU_NB
# freq                                      3585                12306
#
#                                           indicator.label    sex    sex.label  \
# count                                               12306  12306        12306
# unique                                                  1      1            1
# top     Indicador ODS 8.5.1 - Ganancias por hora prome...  SEX_T  Sexo: Total
# freq                                                12306  12306        12306
#
# ...

# %% [markdown]
# Rango temporal de datos  (1991-2022)

# %%
df_ganancias_hora_asalariados['time'].value_counts()
# Out:
# 2018    1064
# 2014    1039
# 2019     904
# 2017     876
# 2010     793
# 2016     750
# 2015     709
# 2020     689
# 2013     646
# 2021     610
# 2012     601
# 2006     558
# 2011     460
# 2009     419
# 2002     401
# 2008     355
# 2007     336
# 2005     252
# 2003     171
# 2004     155
# 2001     153
# 2000      83
# 1998      47
# 1999      46
# 1992      34
# 1994      34
# 1996      34
# 1991      22
# 1997      17
# 1995      17
# 1993      17
# 2022      14
# Name: time, dtype: int64

# %% [markdown]
# ### Sugested Data-Wrangling

# %% [markdown]
# - [ ] Desechar dataset por divisa

# %% [markdown]
# - [ ] Cambio % anual no disponible

# %% [markdown]
# # OECD Average wages

# %% [markdown]
# Fuente : https://data.oecd.org/earnwage/average-wages.htm#indicator-chart

# %% [markdown]
# Average wages are obtained by dividing the national-accounts-based total wage bill by the average number of employees in the total economy, which is then multiplied by the ratio of the average usual weekly hours per full-time employee to the average usually weekly hours for all employees. This indicator is measured in USD constant prices using 2016 base year and Purchasing Power Parities (PPPs) for private consumption of the same year.

# %%
df_average_wages = pd.read_csv(r'average_wages.csv', sep=',', header=0)
df_average_wages
# Out:
#      LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME         Value  \
# 0         AUS    AVWAGE     TOT     USD         A  1990  40519.083621
# 1         AUS    AVWAGE     TOT     USD         A  1991  40328.934866
# 2         AUS    AVWAGE     TOT     USD         A  1992  41135.798085
# 3         AUS    AVWAGE     TOT     USD         A  1993  41513.545516
# 4         AUS    AVWAGE     TOT     USD         A  1994  41789.766398
# ...       ...       ...     ...     ...       ...   ...           ...
# 1074      TUR    AVWAGE     TOT     USD         A  2016  30653.260715
# 1075      TUR    AVWAGE     TOT     USD         A  2017  30076.378939
# 1076      TUR    AVWAGE     TOT     USD         A  2018  30610.715156
# 1077      TUR    AVWAGE     TOT     USD         A  2019  32625.050808
# 1078      TUR    AVWAGE     TOT     USD         A  2020  32482.671310
#
#       Flag Codes
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...

# %% [markdown]
# Información de dataframe

# %%
df_average_wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    1079 non-null   object
#  1   INDICATOR   1079 non-null   object
#  2   SUBJECT     1079 non-null   object
#  3   MEASURE     1079 non-null   object
#  4   FREQUENCY   1079 non-null   object
#  5   TIME        1079 non-null   int64
#  6   Value       1079 non-null   float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 67.6+ KB

# %% [markdown]
# Valores nulos por columna:

# %%
df_average_wages.isnull().sum()
# Out:
# LOCATION         0
# INDICATOR        0
# SUBJECT          0
# MEASURE          0
# FREQUENCY        0
# TIME             0
# Value            0
# Flag Codes    1079
# dtype: int64

# %% [markdown]
# Registros duplicados

# %%
df_average_wages.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción del Dataframe

# %%
# Valores numéricos
df_average_wages.describe()
# Out:
#               TIME         Value  Flag Codes
# count  1079.000000   1079.000000         0.0
# mean   2006.305839  40219.510493         NaN
# std       8.908475  14089.481756         NaN
# min    1990.000000   9316.463455         NaN
# 25%    1999.000000  29248.389808         NaN
# 50%    2006.000000  40454.998494         NaN
# 75%    2014.000000  50391.934050         NaN
# max    2021.000000  74737.845354         NaN

# %%
# Valores no numéricos
df_average_wages.describe(include=[object])
# Out:
#        LOCATION INDICATOR SUBJECT MEASURE FREQUENCY
# count      1079      1079    1079    1079      1079
# unique       36         1       1       1         1
# top         CHE    AVWAGE     TOT     USD         A
# freq         32      1079    1079    1079      1079

# %% [markdown]
# ### Sugested Data Wrangling

# %% [markdown]
# - [x] Eliminar columna 'Flag Codes', 'Frequency', 'Measure', 'Subject', 'Indicator'

# %% [markdown]
# - [x] Renombrar columnas

# %% [markdown]
# # OECD Gender wage gap

# %% [markdown]
# Fuente: https://data.oecd.org/earnwage/gender-wage-gap.htm#indicator-chart

# %% [markdown]
# The gender wage gap is defined as the difference between median earnings of men and women relative to median earnings of men. Data refer to full-time employees on the one hand and to self-employed on the other.

# %%
df_gender_wage_gap = pd.read_csv(r'gender_wage_gap.csv', sep=',', header=0 )
df_gender_wage_gap
# Out:
#      LOCATION INDICATOR   SUBJECT MEASURE FREQUENCY  TIME      Value  \
# 0         AUS   WAGEGAP  EMPLOYEE      PC         A  1975  21.582734
# 1         AUS   WAGEGAP  EMPLOYEE      PC         A  1976  20.754717
# 2         AUS   WAGEGAP  EMPLOYEE      PC         A  1977  18.390805
# 3         AUS   WAGEGAP  EMPLOYEE      PC         A  1978  19.791667
# 4         AUS   WAGEGAP  EMPLOYEE      PC         A  1979  20.000000
# ...       ...       ...       ...     ...       ...   ...        ...
# 1239      BRA   WAGEGAP  EMPLOYEE      PC         A  2017  13.333333
# 1240      BRA   WAGEGAP  EMPLOYEE      PC         A  2018  10.666667
# 1241      BRA   WAGEGAP  EMPLOYEE      PC         A  2019   6.666667
# 1242      BRA   WAGEGAP  EMPLOYEE      PC         A  2020   6.250000
# 1243      BRA   WAGEGAP  EMPLOYEE      PC         A  2021   9.090909
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# ...

# %% [markdown]
# Información del dataframe

# %%
df_gender_wage_gap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    1244 non-null   object
#  1   INDICATOR   1244 non-null   object
#  2   SUBJECT     1244 non-null   object
#  3   MEASURE     1244 non-null   object
#  4   FREQUENCY   1244 non-null   object
#  5   TIME        1244 non-null   int64
#  6   Value       1244 non-null   float64
#  7   Flag Codes  2 non-null      object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 77.9+ KB

# %% [markdown]
# Valores nulos por columna

# %%
df_gender_wage_gap.isnull().sum()
# Out:
# LOCATION         0
# INDICATOR        0
# SUBJECT          0
# MEASURE          0
# FREQUENCY        0
# TIME             0
# Value            0
# Flag Codes    1242
# dtype: int64

# %% [markdown]
# Valores duplicados

# %%
df_gender_wage_gap.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción del Dataframe

# %%
# Valores numéricos
df_gender_wage_gap.describe()
# Out:
#               TIME        Value
# count  1244.000000  1244.000000
# mean   2007.666399    22.423108
# std       9.843283    13.618658
# min    1970.000000   -30.379969
# 25%    2004.000000    12.708804
# 50%    2010.000000    19.667670
# 75%    2015.000000    32.026013
# max    2021.000000    63.200001

# %%
# Valores no numéricos 
df_gender_wage_gap.describe(include=[object])
# Out:
#        LOCATION INDICATOR   SUBJECT MEASURE FREQUENCY Flag Codes
# count      1244      1244      1244    1244      1244          2
# unique       47         1         2       1         1          1
# top         GBR   WAGEGAP  EMPLOYEE      PC         A          B
# freq         66      1244       800    1244      1244          2

# %% [markdown]
# Valores de Subject

# %%
df_gender_wage_gap['SUBJECT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Sugested Data-Wrangling

# %% [markdown]
# - [x] Eliminar columna 'Flag Codes', 'INDICATOR', 'MEASURE', 'FRECUENCY'

# %% [markdown]
# - [x] Cambiar nombre de columnas

# %% [markdown]
# - [x] Crear tabla con pk para SUBJECT

# %% [markdown]
# - [x] Reducir marco temporal

# %% [markdown]
# # OECD Wage levels

# %% [markdown]
# Wage levels are divided by low pay and high pay. The incidence of low pay refers to the share of workers earning less than two-thirds of median earnings. The incidence of high pay refers to the share of workers earning more than one-and-a-half time median earnings. Data refer to full-time employees.This indicator is measured in percentages.

# %%
df_wage_levels = pd.read_csv(r'wage_levels.csv', sep=',', header=0)
df_wage_levels
# Out:
#      LOCATION  INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value  \
# 0         AUS  WAGELEVEL    LPAY      PC         A  1975  11.250855
# 1         AUS  WAGELEVEL    LPAY      PC         A  1976  11.590103
# 2         AUS  WAGELEVEL    LPAY      PC         A  1977  11.706900
# 3         AUS  WAGELEVEL    LPAY      PC         A  1978  12.772322
# 4         AUS  WAGELEVEL    LPAY      PC         A  1979  13.589887
# ...       ...        ...     ...     ...       ...   ...        ...
# 1108      BRA  WAGELEVEL    HPAY      PC         A  2017  24.633931
# 1109      BRA  WAGELEVEL    HPAY      PC         A  2018  25.245748
# 1110      BRA  WAGELEVEL    HPAY      PC         A  2019  26.264624
# 1111      BRA  WAGELEVEL    HPAY      PC         A  2020  29.093154
# 1112      BRA  WAGELEVEL    HPAY      PC         A  2021  28.723718
#
#       Flag Codes
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1108         NaN
# ...

# %% [markdown]
# Información del Dataframe

# %%
df_wage_levels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113 entries, 0 to 1112
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    1113 non-null   object
#  1   INDICATOR   1113 non-null   object
#  2   SUBJECT     1113 non-null   object
#  3   MEASURE     1113 non-null   object
#  4   FREQUENCY   1113 non-null   object
#  5   TIME        1113 non-null   int64
#  6   Value       1113 non-null   float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 69.7+ KB

# %% [markdown]
# Valores nulos por columna

# %%
df_wage_levels.isnull().sum()
# Out:
# LOCATION         0
# INDICATOR        0
# SUBJECT          0
# MEASURE          0
# FREQUENCY        0
# TIME             0
# Value            0
# Flag Codes    1113
# dtype: int64

# %% [markdown]
# Valores duplicados

# %%
df_wage_levels.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción del dataframe

# %%
# Valores numéricos
df_wage_levels.describe()
# Out:
#               TIME        Value  Flag Codes
# count  1113.000000  1113.000000         0.0
# mean   2008.041330    18.461213         NaN
# std      10.208532     6.177030         NaN
# min    1970.000000     0.524876         NaN
# 25%    2003.000000    14.752998         NaN
# 50%    2010.000000    19.001900         NaN
# 75%    2016.000000    22.690675         NaN
# max    2021.000000    34.999981         NaN

# %%
# Valores no numéricos
df_wage_levels.describe(include=[object])
# Out:
#        LOCATION  INDICATOR SUBJECT MEASURE FREQUENCY
# count      1113       1113    1113    1113      1113
# unique       45          1       2       1         1
# top         DEU  WAGELEVEL    LPAY      PC         A
# freq         58       1113     729    1113      1113

# %% [markdown]
# Valores y frecuencia en SUBJECT

# %%
df_wage_levels['SUBJECT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Sugested Data-Wrangling

# %% [markdown]
# - [x] Eliminar columnas 'Flag Codes', 'INDICATOR', 'MEASURE', 'FREQUENCY'

# %% [markdown]
# - [x] En tabla de hechos hacer foreign key 'Subject'

# %% [markdown]
# - [x] Normalizar nombre de columnas

# %% [markdown]
# - [x] Reducir marco temporal si es necesario

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=999c94f3-f6d3-4d70-8bdc-da229abe628a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
