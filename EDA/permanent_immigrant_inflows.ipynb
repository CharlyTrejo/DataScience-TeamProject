# %% [markdown]
# # EDA

# %% [markdown]
# Fuente del dataset : https://data.oecd.org/migration/permanent-immigrant-inflows.htm

# %% [markdown]
# Permanent immigrant inflows cover regulated movements of foreigners considered to be settling in the country from the perspective of the destination country. They cover regulated movements of foreigners as well as free movement migration. The data presented are the result of a standardisation process that allows for cross-country comparisons. This indicator is measured by numbers of permanent inflows.

# %%
import pandas as pd

# %%
df_permanent_immigrant_inflows = pd.read_csv(r'permanent_immigrant_inflows.csv', sep=',', header=0)
df_permanent_immigrant_inflows
# Out:
#      LOCATION    INDICATOR   SUBJECT MEASURE FREQUENCY  TIME    Value  \
# 0         AUS  IMMIGINFLOW       FAM     NBR         A  2003  40105.0
# 1         AUS  IMMIGINFLOW       FAM     NBR         A  2004  42187.0
# 2         AUS  IMMIGINFLOW       FAM     NBR         A  2005  43747.0
# 3         AUS  IMMIGINFLOW       FAM     NBR         A  2006  45943.0
# 4         AUS  IMMIGINFLOW       FAM     NBR         A  2007  48769.0
# ...       ...          ...       ...     ...       ...   ...      ...
# 2936      KOR  IMMIGINFLOW  FREEMOVS     NBR         A  2013      0.0
# 2937      KOR  IMMIGINFLOW  FREEMOVS     NBR         A  2014      0.0
# 2938      KOR  IMMIGINFLOW  FREEMOVS     NBR         A  2015      0.0
# 2939      KOR  IMMIGINFLOW  FREEMOVS     NBR         A  2016      0.0
# 2940      KOR  IMMIGINFLOW  FREEMOVS     NBR         A  2017      0.0
#
#       Flag Codes
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...

# %%
df_permanent_immigrant_inflows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2941 entries, 0 to 2940
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    2941 non-null   object
#  1   INDICATOR   2941 non-null   object
#  2   SUBJECT     2941 non-null   object
#  3   MEASURE     2941 non-null   object
#  4   FREQUENCY   2941 non-null   object
#  5   TIME        2941 non-null   int64
#  6   Value       2941 non-null   float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 183.9+ KB

# %%
df_permanent_immigrant_inflows.isnull().sum()
# Out:
# LOCATION         0
# INDICATOR        0
# SUBJECT          0
# MEASURE          0
# FREQUENCY        0
# TIME             0
# Value            0
# Flag Codes    2941
# dtype: int64

# %%
df_permanent_immigrant_inflows.duplicated().sum()
# Out:
# 0

# %%
df_permanent_immigrant_inflows['SUBJECT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Sugested Data Wrangling

# %% [markdown]
# - [x] Eliminar columnas 'INDICATOR', 'MEASURE', 'FREQUENCY', 'Flag Codes'

# %% [markdown]
# - [x] Normalizar nombre de columnas

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=999c94f3-f6d3-4d70-8bdc-da229abe628a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
