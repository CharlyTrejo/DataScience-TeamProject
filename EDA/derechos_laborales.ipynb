# %% [markdown]
# Fuente de dataset: https://www.ilo.org/shinyapps/bulkexplorer33/?lang=es&id=SDG_0131_SEX_SOC_RT_A

# %% [markdown]
# 'Indicador 8.8.2 Nivel de cumplimiento nacional de los derechos laborales(libertad sindical y negociación colectiva) basado en fuentes textuales de la OIT y la legislación nacional-Anual'

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r'regulacion_juridica_al_empleo', sep=',', header=0)
df
# Out:
#      ref_area ref_area.label    source  \
# 0         AGO         Angola  XA:15876
# 1         AGO         Angola  XA:15876
# 2         AGO         Angola  XA:15876
# 3         ALB        Albania  XA:15877
# 4         ALB        Albania  XA:15877
# ...       ...            ...       ...
# 1231      ZWE       Zimbabwe  XA:15759
# 1232      ZWE       Zimbabwe  XA:15759
# 1233      ZWE       Zimbabwe  XA:15759
# 1234      ZWE       Zimbabwe  XA:15759
# 1235      ZWE       Zimbabwe  XA:15759
#
#                                            source.label        indicator  \
# 0     OIT - Cálculos basados en información de fuent...  SDG_0882_NOC_RT
# 1     OIT - Cálculos basados en información de fuent...  SDG_0882_NOC_RT
# 2     OIT - Cálculos basados en información de fuent...  SDG_0882_NOC_RT
# 3     OIT - Cálculos basados en información de fuent...  SDG_0882_NOC_RT
# 4     OIT - Cálculos basados en información de fuent...  SDG_0882_NOC_RT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ref_area         1236 non-null   object
#  1   ref_area.label   1236 non-null   object
#  2   source           1236 non-null   object
#  3   source.label     1236 non-null   object
#  4   indicator        1236 non-null   object
#  5   indicator.label  1236 non-null   object
#  6   time             1236 non-null   int64
#  7   obs_value        1236 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 77.4+ KB

# %%
df.isnull().sum()
# Out:
# ref_area           0
# ref_area.label     0
# source             0
# source.label       0
# indicator          0
# indicator.label    0
# time               0
# obs_value          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción de dataframe

# %%
# Valores numéricos
df.describe()
# Out:
#               time    obs_value
# count  1236.000000  1236.000000
# mean   2017.486246     2.433487
# std       1.709409     2.440291
# min    2015.000000     0.000000
# 25%    2016.000000     0.690000
# 50%    2017.000000     1.645000
# 75%    2019.000000     3.130000
# max    2020.000000    10.000000

# %%
# Valores no numéricos
df.describe(include=[object])
# Out:
#        ref_area ref_area.label    source  \
# count      1236           1236      1236
# unique      214            214       214
# top         X34      Sri Lanka  XA:15883
# freq          6              6         6
#
#                                              source.label        indicator  \
# count                                                1236             1236
# unique                                                  1                1
# top     OIT - Cálculos basados en información de fuent...  SDG_0882_NOC_RT
# freq                                                 1236             1236
#
#                                           indicator.label
# count                                                1236
# unique                                                  1
# top     Indicador 8.8.2 - Nivel de cumplimiento nacion...
# freq                                                 1236

# %% [markdown]
# Rango temporal de datos

# %%
df['time'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Sugested Data-Wrangling

# %% [markdown]
# - [ ] Renombrar columnas

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=999c94f3-f6d3-4d70-8bdc-da229abe628a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
