# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Ingesta de dataset en dataframe

# %%
df = pd.read_csv(r'distribution-human-rights.csv', sep=',', header=0)
df
# Out:
#             Entity Code  Year  civ_libs_vdem_owid  region
# 0      Afghanistan  AFG  1789               0.122    Asia
# 1      Afghanistan  AFG  1790               0.122    Asia
# 2      Afghanistan  AFG  1791               0.122    Asia
# 3      Afghanistan  AFG  1792               0.122    Asia
# 4      Afghanistan  AFG  1793               0.122    Asia
# ...            ...  ...   ...                 ...     ...
# 33621     Zimbabwe  ZWE  2017               0.434  Africa
# 33622     Zimbabwe  ZWE  2018               0.428  Africa
# 33623     Zimbabwe  ZWE  2019               0.391  Africa
# 33624     Zimbabwe  ZWE  2020               0.399  Africa
# 33625     Zimbabwe  ZWE  2021               0.360  Africa
#
# [33626 rows x 5 columns]

# %% [markdown]
# Información de dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33626 entries, 0 to 33625
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Entity              33626 non-null  object
#  1   Code                31637 non-null  object
#  2   Year                33626 non-null  int64
#  3   civ_libs_vdem_owid  32969 non-null  float64
#  4   region              33626 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# Valores nulos por columna

# %%
df.isnull().sum()
# Out:
# Entity                   0
# Code                  1989
# Year                     0
# civ_libs_vdem_owid     657
# region                   0
# dtype: int64

# %% [markdown]
# Valores duplicados

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descripción de dataframe

# %%
# Valores numéricos
df.describe()
# Out:
#                Year  civ_libs_vdem_owid
# count  33626.000000        32969.000000
# mean    1920.746060            0.439277
# std       65.250368            0.273734
# min     1789.000000            0.009000
# 25%     1866.000000            0.204000
# 50%     1929.000000            0.378953
# 75%     1976.000000            0.650000
# max     2021.000000            0.978000

# %%
# Valores no numéricos
df.describe(include=[object])
# Out:
#          Entity   Code  region
# count     33626  31637   33626
# unique      209    194       7
# top     Hungary    GRC  Europe
# freq        233    233    9719

# %% [markdown]
# Rango temporal de datos

# %%
df['Year'].value_counts()
# Out:
# 2015    186
# 2019    186
# 2017    186
# 2009    186
# 2011    186
#        ...
# 1791     93
# 1790     93
# 1793     93
# 1794     93
# 1792     93
# Name: Year, Length: 233, dtype: int64

# %% [markdown]
# Datos desde el año 1792 a 2015

# %% [markdown]
# ### ETL sugerido

# %% [markdown]
# - [x] Eliminar registros con valores nulos en la columna 'civ_libs_vdem_owid'

# %% [markdown]
# - [x] Reducir rango temporal

# %% [markdown]
# - [x] Renombrar columnas

# %% [markdown]
# - [x] Imputar código de países

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=999c94f3-f6d3-4d70-8bdc-da229abe628a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
