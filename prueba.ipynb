# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Cargo el dataset

# %%
df = pd.read_csv("dataset/talent_linkedin/country_migration_public.csv", usecols=["base_country_code", "base_country_name", "base_lat", "base_long", "base_country_wb_income", "target_country_code", "target_country_name", "target_lat", "target_long", "target_country_wb_income", "target_country_wb_region", "net_per_10K_2015", "net_per_10K_2016", "net_per_10K_2017", "net_per_10K_2018", "net_per_10K_2019"])

# %%
df.head()
# Out:
#   base_country_code     base_country_name   base_lat  base_long  \
# 0                ae  United Arab Emirates  23.424076  53.847818
# 1                ae  United Arab Emirates  23.424076  53.847818
# 2                ae  United Arab Emirates  23.424076  53.847818
# 3                ae  United Arab Emirates  23.424076  53.847818
# 4                ae  United Arab Emirates  23.424076  53.847818
#
#   base_country_wb_income target_country_code target_country_name  target_lat  \
# 0            High Income                  af         Afghanistan   33.939110
# 1            High Income                  dz             Algeria   28.033886
# 2            High Income                  ao              Angola  -11.202692
# 3            High Income                  ar           Argentina  -38.416097
# 4            High Income                  am             Armenia   40.069099
#
#    target_long target_country_wb_income    target_country_wb_region  \
# ...

# %%
df.shape
# Out:
# (4148, 16)

# %% [markdown]
# Filtro según el pais de origen == Argentina

# %%
df_filtro = df[df["base_country_name"] == "Argentina"].sort_values(by=["net_per_10K_2019"])
df_filtro.head()
# Out:
#     base_country_code base_country_name   base_lat  base_long  \
# 175                ar         Argentina -38.416097 -63.616672
# 178                ar         Argentina -38.416097 -63.616672
# 179                ar         Argentina -38.416097 -63.616672
# 156                ar         Argentina -38.416097 -63.616672
# 150                ar         Argentina -38.416097 -63.616672
#
#     base_country_wb_income target_country_code target_country_name  \
# 175            High Income                  es               Spain
# 178            High Income                  gb      United Kingdom
# 179            High Income                  us       United States
# 156            High Income                  cl               Chile
# 150            High Income                  au           Australia
#
#      target_lat  target_long target_country_wb_income  \
# 175   40.463667    -3.749220              High Income
# 178   55.378051    -3.435973              High Income
# ...

# %%
df_filtro2 = df[df["base_country_name"] == "United States"].sort_values(by=["net_per_10K_2019"])
df_filtro2.loc[:, ["base_country_name", "target_country_name", "net_per_10K_2019"]]
# Out:
#      base_country_name target_country_name  net_per_10K_2019
# 3954     United States        Saudi Arabia             -0.29
# 3977     United States      United Kingdom             -0.23
# 3960     United States        South Africa             -0.22
# 3870     United States              Canada             -0.21
# 3903     United States           Indonesia             -0.16
# ...                ...                 ...               ...
# 3947     United States         Philippines              0.26
# 3980     United States       Venezuela, RB              0.30
# 3865     United States              Brazil              0.33
# 3939     United States             Nigeria              0.37
# 3902     United States               India              1.49
#
# [139 rows x 3 columns]

# %% [markdown]
# Obtenemos el top3 de países inmigrantes y emigrantes

# %%
a = df_filtro.iloc[:3]
b = df_filtro.iloc[-3:]
s = pd.concat([a,b])

# %%
s
# Out:
#     base_country_code base_country_name   base_lat  base_long  \
# 175                ar         Argentina -38.416097 -63.616672
# 178                ar         Argentina -38.416097 -63.616672
# 179                ar         Argentina -38.416097 -63.616672
# 173                ar         Argentina -38.416097 -63.616672
# 180                ar         Argentina -38.416097 -63.616672
# 181                ar         Argentina -38.416097 -63.616672
#
#     base_country_wb_income target_country_code target_country_name  \
# 175            High Income                  es               Spain
# 178            High Income                  gb      United Kingdom
# 179            High Income                  us       United States
# 173            High Income                  py            Paraguay
# 180            High Income                  uy             Uruguay
# 181            High Income                  ve       Venezuela, RB
#
#      target_lat  target_long target_country_wb_income  \
# ...

# %% [markdown]
# Cargamos otro dataset

# %%
df2 = pd.read_csv("dataset/talent_linkedin/skill_migration_public.csv", usecols=["country_code","country_name","wb_income","wb_region","skill_group_id","skill_group_category","skill_group_name","net_per_10K_2015","net_per_10K_2016","net_per_10K_2017","net_per_10K_2018","net_per_10K_2019"])
df2.head(5)
# Out:
#   country_code country_name   wb_income   wb_region  skill_group_id  \
# 0           af  Afghanistan  Low income  South Asia          2549.0
# 1           af  Afghanistan  Low income  South Asia          2608.0
# 2           af  Afghanistan  Low income  South Asia          3806.0
# 3           af  Afghanistan  Low income  South Asia         50321.0
# 4           af  Afghanistan  Low income  South Asia          1606.0
#
#           skill_group_category        skill_group_name  net_per_10K_2015  \
# 0                  Tech Skills  Information Management           -791.59
# 1              Business Skills  Operational Efficiency          -1610.25
# 2  Specialized Industry Skills       National Security          -1731.45
# 3                  Tech Skills        Software Testing           -957.50
# 4  Specialized Industry Skills                    Navy          -1510.71
#
#    net_per_10K_2016  net_per_10K_2017  net_per_10K_2018  net_per_10K_2019
# ...

# %%
df2.shape
# Out:
# (20647, 12)

# %% [markdown]
# Filtramos por pais que sea Argentina

# %%
df2_filtro = df2[df2["country_name"]=="Argentina"].sort_values(by="net_per_10K_2019")
df2_filtro
# Out:
#     country_code country_name    wb_income                   wb_region  \
# 363           ar    Argentina  High income  Latin America & Caribbean
# 364           ar    Argentina  High income  Latin America & Caribbean
# 365           ar    Argentina  High income  Latin America & Caribbean
# 366           ar    Argentina  High income  Latin America & Caribbean
# 367           ar    Argentina  High income  Latin America & Caribbean
# ..           ...          ...          ...                         ...
# 529           ar    Argentina  High income  Latin America & Caribbean
# 530           ar    Argentina  High income  Latin America & Caribbean
# 531           ar    Argentina  High income  Latin America & Caribbean
# 532           ar    Argentina  High income  Latin America & Caribbean
# 533           ar    Argentina  High income  Latin America & Caribbean
#
#      skill_group_id         skill_group_category            skill_group_name  \
# ...

# %% [markdown]
# Habilidades de Argentina en auge y en caída

# %%
df2_filtro.loc[:,["country_name", "skill_group_category", "skill_group_name", "net_per_10K_2019"]]
# Out:
#     country_name         skill_group_category            skill_group_name  \
# 363    Argentina  Specialized Industry Skills                   Sociology
# 364    Argentina              Business Skills         Affiliate Marketing
# 365    Argentina              Business Skills                 Sales Leads
# 366    Argentina  Specialized Industry Skills           Industrial Design
# 367    Argentina              Business Skills            Revenue Analysis
# ..           ...                          ...                         ...
# 529    Argentina  Specialized Industry Skills  Electronic Control Systems
# 530    Argentina  Specialized Industry Skills                   Utilities
# 531    Argentina  Specialized Industry Skills             Instrumentation
# 532    Argentina  Specialized Industry Skills                   Oil & Gas
# 533    Argentina  Specialized Industry Skills        Drilling Engineering
#
#      net_per_10K_2019
# 363           -327.67
# 364           -323.41
# ...
